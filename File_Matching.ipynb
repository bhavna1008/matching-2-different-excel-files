# %% [markdown]
# <a href="https://colab.research.google.com/github/sbhawanas/matching-2-different-excel-files/blob/main/File_Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
rb = pd.read_excel("/content/drive/My Drive/Colab Data Files/Adani Sept.xlsx")
print(rb)
rb1 = pd.read_excel("/content/drive/My Drive/Colab Data Files/Signo Sept.xlsx")
print(rb1)
# Out:
#              vno-date
# 0     MP66H2720-44830
# 1     MP66H2716-44830
# 2     MP66H2717-44830
# 3     MP66H2729-44829
# 4     MP66H2691-44829
# ...               ...
# 1085  MP66H2735-44804
# 1086  MP66H2755-44804
# 1087  MP66H2725-44804
# 1088  MP66H2719-44804
# 1089  MP66H2740-44803
#
# [1090 rows x 1 columns]
#              vno-date
# 0     MP66H2739-44834
# 1     MP66H2722-44834
# 2     MP66H2678-44834
# 3     MP66H2756-44834
# 4     MP66H2755-44834
# ...               ...
# 2527  MP66H2747-44807
# 2528  MP66H2722-44807
# 2529  MP66H2704-44807
# 2530  MP66H2671-44807
# 2531  MP66H2719-44807
#
# [2532 rows x 1 columns]

# %%
dict1 = rb.to_dict('index')
print(dict1)
dict2 = rb1.to_dict('index')
print(dict2)
# Out:
# {0: {'vno-date': 'MP66H2720-44830'}, 1: {'vno-date': 'MP66H2716-44830'}, 2: {'vno-date': 'MP66H2717-44830'}, 3: {'vno-date': 'MP66H2729-44829'}, 4: {'vno-date': 'MP66H2691-44829'}, 5: {'vno-date': 'MP66H2731-44829'}, 6: {'vno-date': 'MP66H2730-44829'}, 7: {'vno-date': 'MP66H2747-44829'}, 8: {'vno-date': 'MP66H2745-44829'}, 9: {'vno-date': 'MP66H2694-44829'}, 10: {'vno-date': 'MP66H2752-44829'}, 11: {'vno-date': 'MP66H2751-44829'}, 12: {'vno-date': 'MP66H2732-44829'}, 13: {'vno-date': 'MP66H2746-44829'}, 14: {'vno-date': 'MP66H2755-44829'}, 15: {'vno-date': 'MP66H2754-44829'}, 16: {'vno-date': 'MP66H2674-44829'}, 17: {'vno-date': 'MP66H2678-44829'}, 18: {'vno-date': 'MP66H2721-44829'}, 19: {'vno-date': 'MP66H2724-44829'}, 20: {'vno-date': 'MP66H2742-44829'}, 21: {'vno-date': 'MP66H2698-44829'}, 22: {'vno-date': 'MP66H2710-44829'}, 23: {'vno-date': 'MP66H2703-44829'}, 24: {'vno-date': 'MP66H2740-44829'}, 25: {'vno-date': 'MP66H2738-44829'}, 26: {'vno-date': 'MP66H2750-44829'}, 27: {'vn
# ...

# %%
'''dict3 =  {}
dict3.update({"name": "Testing"})
print(dict3)'''
# Out:
# {'name': 'Testing'}

# %%
c=0
for Vehicle,Start in dict2.items():
  c+=1
    #print(Vehicle,":",Start)
print(c)
# Out:
# 1442

# %%
cnt = 0
for i,j in dict1.items():
    if any ([True for i,j in dict2.items()]):
        cnt+=1
        #print("Matched",i,j)
        #print(dict1.key())
        dict2.pop(i,j)
        
#print(dict1)
print(cnt)
#print(dict2)
        
        #dict3.update({i,":",j})
# Out:
# 1090

# %%
'''for Vehicle,Start in dict2.items():
    print(Vehicle,":",Start)'''
c=0
for Vehicle,Start in dict2.items():
  c+=1
    #print(Vehicle,":",Start)
print(c)
# Out:
# 1442

# %%
difitems= dict2.items() - (dict1.items()

print(difitems)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1ac03b18d52> in <module>
# ----> 1 difitems= set(dict2.items()) - set(dict1.items())
#       2
#       3 print(difitems)
#
# NameError: name 'dict2' is not defined

# %%
c=0
for i,j in dict2.items():
  if (i,j is in dict1.items()):
    c+=1

print(c)
# Out:
#   File "<ipython-input-17-5bfe1cd8cf9f>", line 3
#     if (i,j is in dict1.items()):
#                 ^
# SyntaxError: invalid syntax
